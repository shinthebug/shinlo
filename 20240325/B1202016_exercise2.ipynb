# %%
a={'姓名':'賴宏瑋','性別':'男','作業分數':[80,95,100,90]}
a['student ID']='M1129020'
a['作業分數'][1]=100
del a['作業分數'][0]
print(a)
b=a.pop('作業分數')
c=b.pop(0)
d=b.pop(0)
e=b.pop(0)

g=(c+d+e)/3
print(g)
# Out:
# {'姓名': '賴宏瑋', '性別': '男', '作業分數': [100, 100, 90], 'student ID': 'M1129020'}
# 96.66666666666667

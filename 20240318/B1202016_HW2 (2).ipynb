# %%
a='C,B,A'
b=['F','G','H']
a=a.split(',')
c = a+b
c[0]="K"
d=c.pop(2)
print(d)
del c[1:4]
c.append('U')
print(c)
# Out:
# A
# ['K', 'H', 'U']

# %%
a=input('請輸入8位數字')
print(a[4])
# Out:
# 請輸入8位數字01234567
# 4

# %%
a='My ID is B1202016'
a=a.split(' ')
print(len(a))
print(len(a[3]))
# Out:
# 4
# 8

# %%
a="I'm a student"
a=a.split(' ')
print(a[0][2])
# Out:
# m

# %%
year=int(input())

if year<=1582:
 if year%4==0:
  b=1
 else:
  b=0
else :
 if year%4==0:
  if year%100==0:
    if year%400==0:
      b=1
    else: b=0
  else: b=1
 else: b=0

if b==0:
 print(f"{year}是平年")
elif b==1:
 print(f"{year}是閏年")
# Out:
# 2000
# 2000是閏年
